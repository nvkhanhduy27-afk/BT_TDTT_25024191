# %% [markdown]
# # Bài 1
# Nhập vào số nguyên n, in ra màn hình số gấp đôi của n

# %%
n = int(input())
x = n * 2
print(x)
# Out:
# 18

# %% [markdown]
# # Bài 2
#  Một khu đất hình chữ nhật có chiều rộng a, chiều dài b. Người ra xây một khu
# vui chơi hình tròn tại vị trí trung tâm khu đất như hình vẽ. Nhập vào a, b. Hãy tính phần
# diện tích còn để trồng cây xung quanh là bao nhiêu. Biết pi = 3.14, lấy kết quả đến 2
# chữ số phần thập phân.

# %%
a = int(input())
b = int(input())
s_hcn = a * b
r = a / 2
s_ht = 3.14 * (r ** 2)
s_con_lai = s_hcn - s_ht
print(round(s_con_lai, 2))
# Out:
# 15.38

# %% [markdown]
# # Bài 3
# Viết chương trình nhập vào một “kí tự” c, nếu nó là chữ hoa thì in ra chữ thường
# tương ứng và ngược lại nếu nó là chữ thường thì in ra chữ hoa tương ứng của nó. (xem
# trước cấu trúc lựa chọn: if….else, ma)

# %%
n = input()
if n.isupper():
    print(n.lower())
elif n.islower():
    print(n.upper())
else:
    print(n)
# Out:
# C

# %% [markdown]
# # Bài 4
# Viết chương trình nhập vào một “kí tự”, Kiểm tra xem c có phải là kí tự chữ cái
# không (hoa hoặc thường). Nếu đúng thì in ra “{c} là kí tu alphabet”, nếu sai in ra “{c}
# không phải là kí tự alphabet.

# %%
c = input()
if c.isalpha():
    print(f"'{c}' là kí tự alphabet")
else:
    print(f"'{c}' không phải là kí tự alphabet")
# Out:
# 'a' là kí tự alphabet

# %% [markdown]
# # Bài 5
#  Nhập vào chữ cái hoa A, in ra chữ cái thường liền trước chữ cái a thường tương
# ứng của A. Xét TH khi c = ‘A’ là đặc biệt.

# %%
A_hoa = input("Nhập vào chữ cái hoa: ")
a_thuong = A_hoa.lower()
if A_hoa == 'A':
    print("Ký tự liền trước 'a' là: z")
else:
    ma_truoc = ord(a_thuong) - 1
    chu_truoc = chr(ma_truoc)
    print(f"Ký tự liền trước '{a_thuong}' là: {chu_truoc}")
# Out:
# Ký tự liền trước 'e' là: d

# %% [markdown]
# # Bài 6
#  Nhập vào 3 số a, b, c. Kiểm tra xem đây có phải là cạnh của 1 tam giác không,
# nếu đúng thì tính diện tích của tam giác đó, in ra với 1 chữ số phần thập phân, nếu nó
# không phải 3 cạnh của tam giác thì in ra “Khong phai 3 canh cua tam giac”.

# %%
import math
a, b, c = map(int, input().split())
print(a, b, c)
if a + b > c and b + c > a and a + c > b:
    p = (a + b + c)/ 2
    s = math.sqrt(p * (p- a) * (p - b) * (p - c))
    print(round(s, 1))
else:
    print("Khong phai 3 canh cua tam giac")
# Out:
# 3 4 5
# 6.0

# %% [markdown]
# # Bài 7
# Nhập vào một chuỗi gồm các kí tự thường độ dài >=20, in ra chữ cái thứ năm và
# thứ chín của chuỗi này.

# %%
s = input("Nhập chuỗi (độ dài >= 20): ")
print(s)
if len(s) >= 20:
    print(f"Ký tự thứ năm: {s[4]}")
    print(f"Ký tự thứ chín: {s[8]}")
# Out:
# 123456789101112131415
# Ký tự thứ năm: 5
# Ký tự thứ chín: 9

# %% [markdown]
# # Bài 8
#  Nhập vào họ tên chủ hộ và chỉ số điện kế tháng trước và chỉ số điện kế tháng này,
# tính tiền điện tháng này cho hộ biết:
# Từ 0 – 50kWh: 1.984 đồng/kWh
# Bậc 2: Từ 51 – 100 kWh: 2.050 đồng/kWh
# Bậc 3: Từ 101 – 200 kWh: 2.380 đồng/kWh
# Bậc 4: Từ 201 – 300 kWh: 2.998 đồng/kWh
# Bậc 5: Từ 301 – 400 kWh: 3.350 đồng/kWh
# Bậc 6: Từ 401 trở đi kWh: 3.460 đồng/kWh

# %%
ten = input("Ten chu ho: ")
cu = int(input("Chi so thang truoc: "))
moi = int(input("Chi so thang nay: "))
kwh = moi - cu
tien = 0
if kwh <= 50:
    tien = kwh * 1984
elif kwh <= 100:
    tien = 50 * 1984 + (kwh - 50) * 2050
elif kwh <= 200:
    tien = 50 * 1984 + 50 * 2050 + (kwh - 100) * 2380
elif kwh <= 300:
    tien = 50 * 1984 + 50 * 2050 + 100 * 2380 + (kwh - 200) * 2998
elif kwh <= 400:
    tien = 50 * 1984 + 50 * 2050 + 100 * 2380 + 100 * 2998 + (kwh - 300) * 3350
else:
    tien = 50 * 1984 + 50 * 2050 + 100 * 2380 + 100 * 2998 + 100 * 3350 + (kwh - 400) * 3460
tong_tien = tien * 1.08
print(f"Ho va ten: {ten}")
print(f"Tien phai tra la: {int(tong_tien)}")
# Out:
# Ho va ten: Nguyễn Văn Khánh Duy
# Tien phai tra la: 47139

# %% [markdown]
# # Một số bài tập khác
# 1. Kiểm tra số chẵn lẻ: Viết chương trình nhập một số nguyên, kiểm tra và in ra số đó
# là số chẵn hay số lẻ.

# %%
n = int(input())
print(n)
if n % 2 == 0:
    print("Là số chẵn")
else:
    print("Là số lẻ")
# Out:
# 17
# Là số lẻ

# %% [markdown]
# #
# 2. Viết chương trình nhập một số nguyên, kiểm tra số đó có tận cùng 5 không, nếu đúng in ra “True”, nếu sai in ra “False”.

# %%
n = int(input())
print(n)
if n % 10 == 5:
    print("True")
else:
    print("False")
# Out:
# 1555
# True

# %% [markdown]
# #
# 3. Viết chương trình nhập một số nguyên,
# kiểm tra số đó có chia hết cho 3 và 5 không, nếu đúng in ra “True”, nếu sai in ra
# “False”.

# %%
n = int(input())
print(n)
if n % 3 == 0 and n % 5 == 0:
    print("True")
else:
    print("False")
# Out:
# 15
# True

# %% [markdown]
# #
# 4.  Viết chương trình nhập năm sinh của một
# người, kiểm tra xem người đó có đủ 18 tuổi để đi bầu cử hay không

# %%
n = int(input())
print(n)
x = 2026 - n
if x >= 18:
    print("Đủ tuổi")
else:
    print("Chưa đủ tuổi")
# Out:
# 2002
# Đủ tuổi

# %% [markdown]
# #
# 5. Viết chương trình nhập vào hai số, in ra số lớn hơn hoặc thông báo
# nếu hai số bằng nhau.

# %%
a, b = map(int, input().split())
print(a, b)
if a < b:
    print(f"Số lớn hơn là: {b}")
elif a > b:
    print(f"Số lớn hơn là: {a}")
elif a == b:
    print("2 số bằng nhau")
# Out:
# 1 3
# Số lớn hơn là: 3

# %% [markdown]
# #
# 6. Viết chương trình nhập một ký tự, kiểm
# tra xem ký tự đó là chữ cái hay số.

# %%
n = input()
print(n)
if n.isdigit():
    print("Là chữ số")
elif n.isalpha():
    print("Là chữ cái")
# Out:
# bb
# Là chữ cái

# %% [markdown]
# #
# 7. Nhập điểm (0-10), phân loại học lực theo quy tắc: >=8: Giỏi; >=6.5 và <8: Khá; >=5 và <6.5: Trung bình; <5: Yếu

# %%
n = int(input())
print(n)
if n >= 8 and n <= 10:
    print("Giỏi")
elif n >= 6.5 and n < 8:
    print("Khá")
elif n >= 5 and n < 6.5:
    print("Trung bình")
elif n < 5:
    print("Yếu")
# Out:
# 5
# Trung bình

# %% [markdown]
# #
# 8. Viết chương trình nhập năm, kiểm tra xem năm đó có phải
# năm nhuận hay không. (Năm nhuận nếu chia hết cho 400 hoặc chia hết cho 4
# nhưng không chia hết cho 100)

# %%
n = int(input())
print(n)
if n % 400 == 0 or n % 4 and n % 100 != 0:
    print("Là năm nhuận")
else:
    print("Không là năm nhuận")
# Out:
# 2024
# Không là năm nhuận

# %% [markdown]
# #
# 9. Chuyển đổi số thành chữ số: Nhập một số nguyên từ 0 đến 9, in ra tên chữ số
# tương ứng (0 -> "Không", 1 -> "Một", ...)

# %%
n = int(input())
match n:
    case 0: print("Không")
    case 1: print("Một")
    case 2: print("Hai")
    case 3: print("Ba")
    case 4: print("Bốn")
    case 5: print("Năm")
    case 6: print("Sáu")
    case 7: print("Bảy")
    case 8: print("Tám")
    case 9: print("Chín")
    case _: print("Số nhập vào không nằm trong khoảng 0-9")
# Out:
# Tám

# %% [markdown]
# #
# 10.  Kiểm tra điểm thi xem có qua môn hay phải học lại: Nhập điểm thi, nếu điểm >=
# 4 thì in "Qua môn", ngược lại in "Học lại".

# %%
n = int(input())
print(n)
if n >= 4:
    print("Qua môn")
elif n < 4:
    print("Học lại")
# Out:
# 4
# Qua môn

# %% [markdown]
# #
# 11. Nhập năm sinh, tính tuổi hiện tại (giả sử năm
# hiện tại là 2025), và kiểm tra xem người đó có đủ 18 tuổi hay chưa.

# %%
n = int(input())
print(n)
tuoi = 2026 - n
if tuoi >= 18:
    print("Đủ 18 tuổi")
else:
    print("Chưa đủ 18 tuổi")
# Out:
# 2000
# Đủ 18 tuổi
