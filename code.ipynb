# %%
student = {"name": "John", "degree": "Master"}
print("Đây là tên", student["name"])
print("Đây là học vị", student["degree"])
# Out:
# Đây là tên John
# Đây là học vị Master

# %%
for key in student:
    print(key)
# Out:
#   Cell In[6], line 2
#     print(list)
#     ^
# IndentationError: unexpected indent
